# %% [markdown]
# Pydantic helps implement data validation and parsing and schema enforcement.
#
# When we use AgenticAISD LLMs of an get the information and we need to submit information to them. So when we are doing such kind of things, we must strictly control data quality.
#
# That is where Pydantic helps
#
# it helps in
# - type coercion
#     'id: int = Field(...) -> id('2') get converted to id(2)'
# - supports json as both input and output
# - helps apply data validation rules and transformatins in the class itself.
